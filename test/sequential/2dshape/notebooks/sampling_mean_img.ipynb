# %%
#import sys
#sys.append("../")

import matplotlib.pyplot as plt
import numpy as np

img = np.load("../data/processed/square_triangle/0010.npy")
for i in range(0, 11):
    plt.imshow(img[99, i])
    plt.gray()
    plt.show()
